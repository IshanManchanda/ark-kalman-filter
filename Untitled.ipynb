# %%
from mpl_toolkits import mplot3d

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
# %%timeit
my_data = np.genfromtxt('data/Data1.csv', delimiter=',')
# Out:
# 152 ms ± 1.57 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
with open('data/Data1.csv') as csv_file:
	data = np.array(list(csv.reader(csv_file)))
# Out:
# 84.9 ms ± 1.25 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
print(my_data.shape)
print(data.shape)
# Out:
# (10000, 18)
# (10000, 18)

# %%
ax = plt.axes(projection='3d')
x = 10000
i = 0
ax.scatter3D(my_data[:x, i], my_data[:x, i + 1], my_data[:x, i + 2], c=range(x), cmap='Greens');

# %%
ax = plt.axes(projection='3d')
x = 10000
i = 15
ax.scatter3D(my_data[:x, i], my_data[:x, i + 1], my_data[:x, i + 2], c=range(x), cmap='Greens');
